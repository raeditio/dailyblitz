# %%
# !pip install ultralytics roboflow

# %% [markdown]
# Download dataset from Roboflow

# %%
from roboflow import Roboflow
from google.colab import userdata
rf = Roboflow(api_key=userdata.get('ROBOFLOW_API_KEY'))
project = rf.workspace("salah-dy7at").project("poker-card-doocc")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# Train the YOLO11 model

# %%
from ultralytics import YOLO
import os

# Load the nano YOLO11 model
model = YOLO('yolo11n.pt')

# Train the model using your downloaded Roboflow dataset
# Note: 'data.yaml' is the file inside the folder you download from Roboflow
yaml_path = os.path.join(dataset.location, "data.yaml")
# Start the training process
model.train(
    data=yaml_path,
    epochs=1000,            # Number of training loops (increase to 100+ if accuracy is low)
    imgsz=2048,
    batch=6,             # Number of images processed at once
    device='',            # Leave empty to automatically use your GPU if available
    project='poker_bot',  # The parent folder where results will be saved
    name='yolo11_poker'   # The specific sub-folder for this training run
)

print("\n--- Training Complete! ---")
# Out:
# New https://pypi.org/project/ultralytics/8.4.75 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.74 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
